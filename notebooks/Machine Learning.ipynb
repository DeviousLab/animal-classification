# %%
import os
import re
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [raw]
# !conda install -c conda-forge scikit-image

# %%
import skimage
import skimage.color
import skimage.io
import skimage.feature
import skimage.transform

# %%
skimage.__version__
# Out:
# '0.19.2'

# %%
# load the data
data = pickle.load(open('data_animals_head_20.pickle','rb'))

# %%
data['description']
# Out:
# 'There are 20 classes and 2057 images are there. All the images are 80 x 80 (rgb)'

# %%
# split the data into independent and dependent
X = data['data'] # independent
y = data['target'] # dependent

# %%
print(X)
# Out:
# [[[[196 214 188]
#    [196 214 188]
#    [196 214 188]
#    ...
#    [ 81  76  80]
#    [ 81  76  80]
#    [ 69  64  68]]
#
#   [[196 214 188]
#    [196 214 188]
#    [196 215 187]
#    ...
#    [ 82  77  81]
#    [ 83  78  82]
#    [ 77  72  76]]
#
#   [[193 213 185]
#    [194 214 186]
#    [194 214 186]
#    ...
#    [ 82  77  81]
#    [ 81  76  80]
#    [ 78  73  77]]
#
#   ...
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 70  65  69]
#    [ 65  60  64]
#    [ 62  57  63]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 66  61  65]
#    [ 62  57  61]
#    [ 64  59  65]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 56  51  55]
#    [ 79  74  78]
#    [ 70  63  70]]]
#
#
#  [[[  4   2   3]
#    [  7   5   6]
#    [  6   5   3]
#    ...
#    [ 42  31  25]
#    [ 46  35  29]
#    [ 45  32  26]]
#
#   [[  7   5   6]
#    [  5   4   2]
#    [  2   1   0]
#    ...
#    [ 22  11   5]
#    [ 43  32  26]
#    [ 47  36  30]]
#
#   [[  6   5   3]
#    [  3   2   0]
#    [  2   1   0]
#    ...
#    [ 33  24  17]
#    [ 48  39  32]
#    [ 54  45  38]]
#
#   ...
#
#   [[ 24  29   6]
#    [ 24  30   4]
#    [ 25  31   5]
#    ...
#    [116 116  80]
#    [115 117  80]
#    [127 129  92]]
#
#   [[ 22  27   4]
#    [ 23  28   5]
#    [ 24  29   6]
#    ...
#    [112 112  76]
#    [115 117  80]
#    [128 130  93]]
#
#   [[ 22  27   5]
#    [ 22  27   4]
#    [ 22  27   4]
#    ...
#    [106 106  70]
#    [112 114  77]
#    [126 128  91]]]
#
#
#  [[[104 109 102]
#    [104 111 103]
#    [108 115 107]
#    ...
#    [130 126 127]
#    [122 117 121]
#    [123 118 122]]
#
#   [[113 118 111]
#    [ 97 104  96]
#    [103 110 102]
#    ...
#    [111 107 108]
#    [129 124 128]
#    [150 145 149]]
#
#   [[126 133 125]
#    [112 119 111]
#    [110 117 109]
#    ...
#    [139 135 136]
#    [162 157 161]
#    [163 158 162]]
#
#   ...
#
#   [[214 214 202]
#    [206 206 194]
#    [202 200 187]
#    ...
#    [164 162 150]
#    [173 173 163]
#    [187 187 179]]
#
#   [[219 219 207]
#    [210 210 198]
#    [205 203 190]
#    ...
#    [170 168 156]
#    [174 174 164]
#    [188 188 180]]
#
#   [[214 214 202]
#    [201 201 189]
#    [198 196 183]
#    ...
#    [172 170 158]
#    [179 179 169]
#    [184 184 176]]]
#
#
#  ...
#
#
#  [[[147 154 113]
#    [145 152 111]
#    [146 153 112]
#    ...
#    [102 109  58]
#    [118 121  74]
#    [128 131  86]]
#
#   [[148 155 114]
#    [146 153 112]
#    [145 152 111]
#    ...
#    [120 128  71]
#    [138 142  91]
#    [151 155 105]]
#
#   [[147 154 112]
#    [146 153 111]
#    [144 151 109]
#    ...
#    [136 142  80]
#    [143 151  91]
#    [150 158  99]]
#
#   ...
#
#   [[137 142  88]
#    [146 150  99]
#    [145 148 101]
#    ...
#    [143 138 100]
#    [148 143 103]
#    [158 150 111]]
#
#   [[133 138  82]
#    [128 133  79]
#    [129 133  83]
#    ...
#    [158 153 115]
#    [157 152 112]
#    [154 149 109]]
#
#   [[130 135  79]
#    [128 133  79]
#    [135 139  88]
#    ...
#    [160 155 115]
#    [157 152 112]
#    [150 145 105]]]
#
#
#  [[[246 250 249]
#    [247 251 250]
#    [252 254 253]
#    ...
#    [136 118 114]
#    [143 124 118]
#    [145 126 120]]
#
#   [[244 248 247]
#    [252 255 255]
#    [243 245 244]
#    ...
#    [139 124 117]
#    [135 120 113]
#    [156 141 134]]
#
#   [[238 242 241]
#    [248 252 251]
#    [246 248 247]
#    ...
#    [128 118 109]
#    [128 118 109]
#    [141 131 122]]
#
#   ...
#
#   [[236 233 224]
#    [230 226 217]
#    [228 224 215]
#    ...
#    [159 142 126]
#    [152 135 119]
#    [150 133 117]]
#
#   [[234 231 222]
#    [233 230 221]
#    [229 225 216]
#    ...
#    [185 169 154]
#    [165 149 134]
#    [169 153 138]]
#
#   [[242 239 232]
#    [236 233 224]
#    [229 225 216]
#    ...
#    [193 177 162]
#    [185 169 154]
#    [175 159 144]]]
#
#
#  [[[ 85  78  32]
#    [ 79  72  26]
#    [ 79  72  26]
#    ...
#    [ 80  73  27]
#    [ 76  69  23]
#    [ 74  67  21]]
#
#   [[ 82  78  31]
#    [ 79  72  26]
#    [ 78  71  25]
#    ...
#    [ 78  71  25]
#    [ 75  68  24]
#    [ 71  64  20]]
#
#   [[ 81  77  30]
#    [ 80  73  27]
#    [ 77  70  24]
#    ...
#    [ 78  71  27]
#    [ 76  69  25]
#    [ 71  64  20]]
#
#   ...
#
#   [[ 85  55  17]
#    [ 92  60  22]
#    [ 90  58  20]
#    ...
#    [103 101  53]
#    [ 99  97  49]
#    [ 96  94  46]]
#
#   [[ 87  57  19]
#    [ 82  50  11]
#    [ 88  56  17]
#    ...
#    [104 100  53]
#    [101  97  50]
#    [ 98  94  47]]
#
#   [[ 82  53  13]
#    [ 83  51  12]
#    [ 92  60  21]
#    ...
#    [101  94  48]
#    [100  93  47]
#    [ 98  91  45]]]]

# %%
print(y)
# Out:
# ['bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', ' ...

# %%
# split the data into train and test
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y)

# %%
x_train.shape,x_test.shape,len(y_train),len(y_test)
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3), 1645, 412)

# %% [markdown]
# ---
# ####  Feature Extraction
# - Hog
# [URL](https://www.analyticsvidhya.com/blog/2019/09/feature-engineering-images-introduction-hog-feature-descriptor/#:~:text=HOG%2C%20or%20Histogram%20of%20Oriented,vision%20tasks%20for%20object%20detection.)

# %%
img = skimage.io.imread('lion.bmp')[:,:,:3]
plt.figure(figsize=(6,10))
plt.imshow(img)
img.shape
# Out:
# (907, 645, 3)

# %%
# hog transoform
img_re = skimage.transform.rescale(img,1/3, channel_axis=2).reshape((302,215,3))
gray = skimage.color.rgb2gray(img_re)
feature_vector, hog_img = skimage.feature.hog(gray,orientations=9,
                    pixels_per_cell=(14,14),
                    cells_per_block=(2,2),
                    visualize=True)

# %%
len(feature_vector)
# Out:
# 102060

# %%
gray.shape
# Out:
# (302, 215, 3)

# %%
302*215
# Out:
# 64930

# %%
plt.figure(figsize=(12,10))
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(hog_img,cmap='gray')

# %% [markdown]
# ---

# %% [markdown]
# ## Preprocessing
# - Grayscale
# - Hog (histogram oriented gradient) tranformer

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from skimage.color import rgb2gray

# %%
class rgb2gray_transform(BaseEstimator,TransformerMixin):
    import skimage.color
    def __init__(self):
        pass
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        return np.array([skimage.color.rgb2gray(x) for x in X])

# %%
x_train.shape
# Out:
# (1645, 80, 80, 3)

# %%
rgb2grayobj = rgb2gray_transform()
x_train_gray = rgb2grayobj.fit_transform(x_train)

# %%
x_train_gray.shape
# Out:
# (1645, 80, 80)

# %%
plt.subplot(1,2,1)
plt.imshow(x_train[12])
plt.subplot(1,2,2)
plt.imshow(x_train_gray[12],cmap='gray')

# %%
class hogtransformer(BaseEstimator,TransformerMixin):
    import skimage.feature
    def __init__(self,orientations=9,pixels_per_cell=(8, 8),cells_per_block=(3, 3),):
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        
        
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        def local_hog(img):
            hog_features = skimage.feature.hog(img,orientations=self.orientations,
                                pixels_per_cell=self.pixels_per_cell,
                                cells_per_block=self.cells_per_block)
            
            return hog_features
        
        hfeatures = np.array([local_hog(x) for x in X])
        return hfeatures

# %%
hogt = hogtransformer()

# %%
x_train_hog = hogt.fit_transform(x_train_gray)

# %%
x_train_hog.shape
# Out:
# (1645, 5184)

# %% [markdown]
# ### Training Machine Learning Model

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
import sklearn.metrics
from sklearn.preprocessing import StandardScaler

# %%
model_sgd = SGDClassifier(loss='hinge',learning_rate='adaptive',
                          early_stopping=True,eta0=0.1,)

# %%
x_train.shape,x_test.shape
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3))

# %%
grayify = rgb2gray_transform()
hogify = hogtransformer()
scalify = StandardScaler()

# %%
# pipeline
# step-1: convert into grayscale
x_train_gray = grayify.fit_transform(x_train)
# step-2: extract the features
x_train_hog = hogify.fit_transform(x_train_gray)
# step-3: Normalization
x_train_scale = scalify.fit_transform(x_train_hog)
# step-4: machine learning
model_sgd.fit(x_train_scale,y_train)
# Out:
# SGDClassifier(early_stopping=True, eta0=0.1, learning_rate='adaptive')

# %%
x_test_gray = grayify.fit_transform(x_test)
# step-2: extract the features
x_test_hog = hogify.fit_transform(x_test_gray)
# step-3: Normalization
x_test_scale = scalify.transform(x_test_hog)

y_pred_test = model_sgd.predict(x_test_scale)

# %%
y_pred_test
# Out:
# array(['human', 'lion', 'monkey', 'lion', 'duck', 'lion', 'dog', 'eagle',
#        'sheep', 'eagle', 'cat', 'cat', 'sheep', 'monkey', 'bear',
#        'pigeon', 'cow', 'human', 'elephant', 'cat', 'cat', 'wolf',
#        'eagle', 'chicken', 'bear', 'chicken', 'elephant', 'duck', 'sheep',
#        'rabbit', 'panda', 'cat', 'cow', 'rabbit', 'eagle', 'cat', 'bear',
#        'duck', 'tiger', 'cow', 'elephant', 'elephant', 'tiger', 'eagle',
#        'bear', 'sheep', 'elephant', 'cow', 'chicken', 'rabbit', 'tiger',
#        'mouse', 'bear', 'chicken', 'cat', 'deer', 'cow', 'pigeon',
#        'human', 'panda', 'cow', 'lion', 'panda', 'deer', 'rabbit', 'lion',
#        'sheep', 'sheep', 'tiger', 'duck', 'panda', 'elephant', 'monkey',
#        'duck', 'elephant', 'panda', 'elephant', 'chicken', 'chicken',
#        'dog', 'panda', 'dog', 'cat', 'rabbit', 'elephant', 'cow', 'bear',
#        'deer', 'deer', 'cow', 'mouse', 'deer', 'sheep', 'cat', 'cat',
#        'lion', 'cow', 'bear', 'cat', 'chicken', 'deer', 'cat', 'dog',
#        'human', 'tiger', 'monkey', 'panda', 'elephant', 'cow', 'dog',
#        'chicken', 'human', 'panda', 'duck', 'deer', 'chicken', 'sheep',
#        'deer', 'chicken', 'lion', 'mouse', 'tiger', 'tiger', 'deer',
#        'human', 'monkey', 'sheep', 'bear', 'panda', 'deer', 'dog',
#        'panda', 'chicken', 'panda', 'wolf', 'pigeon', 'duck', 'elephant',
#        'chicken', 'rabbit', 'elephant', 'lion', 'chicken', 'cow', 'cat',
#        'chicken', 'duck', 'human', 'rabbit', 'human', 'rabbit', 'cow',
#        'duck', 'duck', 'bear', 'chicken', 'sheep', 'human', 'tiger',
#        'chicken', 'rabbit', 'chicken', 'monkey', 'mouse', 'chicken',
#        'human', 'tiger', 'panda', 'elephant', 'tiger', 'mouse', 'deer',
#        'cow', 'cow', 'human', 'human', 'deer', 'monkey', 'monkey', 'duck',
#        'deer', 'duck', 'panda', 'mouse', 'pigeon', 'lion', 'eagle',
#        'pigeon', 'elephant', 'cat', 'panda', 'cow', 'duck', 'panda',
#        'monkey', 'deer', 'bear', 'cat', 'cow', 'bear', 'pigeon', 'wolf',
#        'deer', 'deer', 'cow', 'tiger', 'deer', 'elephant', 'cat', 'sheep',
#        'lion', 'eagle', 'tiger', 'elephant', 'cat', 'pigeon', 'duck',
#        'panda', 'tiger', 'duck', 'lion', 'dog', 'bear', 'sheep', 'pigeon',
#        'cat', 'pigeon', 'pigeon', 'cow', 'eagle', 'human', 'monkey',
#        'natural', 'pigeon', 'monkey', 'human', 'dog', 'tiger', 'cow',
#        'human', 'dog', 'bear', 'chicken', 'eagle', 'deer', 'lion',
#        'panda', 'cat', 'pigeon', 'cat', 'mouse', 'elephant', 'human',
#        'pigeon', 'wolf', 'elephant', 'deer', 'dog', 'deer', 'human',
#        'human', 'rabbit', 'bear', 'panda', 'panda', 'panda', 'monkey',
#        'cat', 'human', 'monkey', 'bear', 'lion', 'eagle', 'human',
#        'pigeon', 'sheep', 'lion', 'lion', 'cat', 'elephant', 'deer',
#        'tiger', 'cat', 'eagle', 'sheep', 'human', 'mouse', 'bear',
#        'human', 'cat', 'eagle', 'panda', 'lion', 'dog', 'human', 'deer',
#        'wolf', 'dog', 'sheep', 'rabbit', 'dog', 'tiger', 'rabbit', 'deer',
#        'bear', 'elephant', 'wolf', 'chicken', 'pigeon', 'panda', 'deer',
#        'duck', 'lion', 'cat', 'pigeon', 'lion', 'wolf', 'chicken', 'bear',
#        'sheep', 'sheep', 'sheep', 'tiger', 'panda', 'cat', 'tiger',
#        'deer', 'cat', 'sheep', 'human', 'panda', 'rabbit', 'panda',
#        'wolf', 'tiger', 'duck', 'dog', 'duck', 'dog', 'panda', 'cat',
#        'tiger', 'lion', 'natural', 'bear', 'sheep', 'pigeon', 'eagle',
#        'panda', 'monkey', 'chicken', 'tiger', 'human', 'deer', 'wolf',
#        'cat', 'elephant', 'eagle', 'monkey', 'duck', 'human', 'dog',
#        'duck', 'mouse', 'sheep', 'lion', 'natural', 'tiger', 'cat',
#        'human', 'panda', 'chicken', 'duck', 'cow', 'cat', 'cat', 'tiger',
#        'duck', 'panda', 'panda', 'tiger', 'sheep', 'sheep', 'cow',
#        'pigeon', 'tiger', 'lion', 'human', 'dog', 'panda', 'cat', 'cat',
#        'dog', 'cat', 'panda', 'sheep', 'cow', 'pigeon', 'cat', 'elephant',
#        'chicken', 'sheep', 'lion', 'lion', 'pigeon', 'duck', 'cat',
#        'mouse', 'lion', 'monkey', 'panda', 'rabbit'], dtype='<U8')

# %% [markdown]
# ### Model Evaluation

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# bear           0.421053  0.400000  0.410256   20.000000
# cat            0.793103  0.718750  0.754098   32.000000
# chicken        0.750000  0.750000  0.750000   20.000000
# cow            0.470588  0.380952  0.421053   21.000000
# deer           0.619048  0.619048  0.619048   21.000000
# dog            0.368421  0.269231  0.311111   26.000000
# duck           0.833333  0.714286  0.769231   21.000000
# eagle          0.346154  0.450000  0.391304   20.000000
# elephant       0.541667  0.650000  0.590909   20.000000
# human          0.548387  0.850000  0.666667   20.000000
# lion           0.400000  0.300000  0.342857   20.000000
# monkey         0.375000  0.300000  0.333333   20.000000
# mouse          0.294118  0.250000  0.270270   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.692308  0.750000  0.720000   24.000000
# pigeon         0.437500  0.304348  0.358974   23.000000
# rabbit         0.500000  0.500000  0.500000   20.000000
# sheep          0.400000  0.600000  0.480000   20.000000
# tiger          0.750000  0.652174  0.697674   23.000000
# wolf           0.583333  0.700000  0.636364   20.000000
# accuracy       0.536408  0.536408  0.536408    0.536408
# macro avg      0.506201  0.507939  0.501158  412.000000
# weighted avg   0.539958  0.536408  0.532131  412.000000

# %%
metrics.cohen_kappa_score(y_test,y_pred_test)
# Out:
# 0.510774013055642

# %% [markdown]
# # Pipeline Model

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipeline = Pipeline([
    ('grayscale',rgb2gray_transform()),
    ('hogtransform',hogtransformer(orientations=8,pixels_per_cell=(10,10),cells_per_block=(3,3))),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier(loss='hinge',learning_rate='adaptive',eta0=0.001))
])

# %%
model_pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('grayscale', rgb2gray_transform()),
#                 ('hogtransform',
#                  hogtransformer(orientations=8, pixels_per_cell=(10, 10))),
#                 ('scale', StandardScaler()),
#                 ('sgd', SGDClassifier(eta0=0.001, learning_rate='adaptive'))])

# %%
y_pred = model_pipeline.predict(x_test)

# %%
y_pred
# Out:
# array(['elephant', 'cow', 'duck', 'rabbit', 'chicken', 'cat', 'monkey',
#        'human', 'cat', 'cat', 'rabbit', 'sheep', 'monkey', 'elephant',
#        'cat', 'deer', 'mouse', 'rabbit', 'tiger', 'cat', 'eagle',
#        'chicken', 'sheep', 'panda', 'mouse', 'cow', 'sheep', 'eagle',
#        'human', 'lion', 'lion', 'elephant', 'cat', 'wolf', 'eagle',
#        'sheep', 'tiger', 'monkey', 'human', 'panda', 'cat', 'rabbit',
#        'dog', 'pigeon', 'lion', 'lion', 'chicken', 'panda', 'lion',
#        'tiger', 'sheep', 'pigeon', 'sheep', 'rabbit', 'eagle', 'deer',
#        'mouse', 'duck', 'lion', 'lion', 'sheep', 'pigeon', 'duck', 'cat',
#        'duck', 'chicken', 'wolf', 'wolf', 'lion', 'monkey', 'duck',
#        'tiger', 'eagle', 'wolf', 'dog', 'sheep', 'monkey', 'cow', 'lion',
#        'eagle', 'tiger', 'sheep', 'cat', 'cat', 'wolf', 'tiger',
#        'elephant', 'cat', 'mouse', 'elephant', 'pigeon', 'tiger',
#        'monkey', 'bear', 'sheep', 'mouse', 'panda', 'chicken', 'sheep',
#        'cat', 'panda', 'eagle', 'duck', 'sheep', 'elephant', 'rabbit',
#        'pigeon', 'human', 'wolf', 'human', 'dog', 'cow', 'elephant',
#        'tiger', 'dog', 'human', 'cat', 'dog', 'duck', 'elephant',
#        'pigeon', 'rabbit', 'lion', 'dog', 'lion', 'tiger', 'cat', 'sheep',
#        'duck', 'cow', 'tiger', 'panda', 'human', 'eagle', 'pigeon',
#        'eagle', 'chicken', 'bear', 'eagle', 'chicken', 'rabbit', 'wolf',
#        'lion', 'pigeon', 'dog', 'duck', 'panda', 'panda', 'cat', 'wolf',
#        'monkey', 'bear', 'human', 'elephant', 'cat', 'wolf', 'mouse',
#        'pigeon', 'pigeon', 'elephant', 'cat', 'deer', 'eagle', 'bear',
#        'bear', 'duck', 'deer', 'cat', 'monkey', 'pigeon', 'cow', 'mouse',
#        'cat', 'deer', 'pigeon', 'duck', 'eagle', 'monkey', 'human',
#        'human', 'panda', 'bear', 'mouse', 'pigeon', 'wolf', 'bear',
#        'tiger', 'dog', 'cat', 'sheep', 'panda', 'sheep', 'tiger',
#        'elephant', 'panda', 'pigeon', 'cow', 'human', 'pigeon', 'cow',
#        'mouse', 'pigeon', 'human', 'wolf', 'cat', 'lion', 'lion', 'tiger',
#        'cat', 'chicken', 'cow', 'cat', 'deer', 'chicken', 'bear', 'dog',
#        'cow', 'cat', 'eagle', 'pigeon', 'elephant', 'dog', 'sheep', 'cow',
#        'rabbit', 'cat', 'lion', 'lion', 'bear', 'duck', 'cat', 'cat',
#        'elephant', 'lion', 'elephant', 'monkey', 'wolf', 'mouse', 'human',
#        'eagle', 'duck', 'dog', 'duck', 'pigeon', 'wolf', 'eagle', 'human',
#        'tiger', 'deer', 'lion', 'pigeon', 'panda', 'elephant', 'cow',
#        'eagle', 'elephant', 'bear', 'rabbit', 'panda', 'deer', 'rabbit',
#        'sheep', 'pigeon', 'deer', 'cat', 'mouse', 'sheep', 'rabbit',
#        'deer', 'deer', 'elephant', 'elephant', 'monkey', 'dog', 'rabbit',
#        'human', 'pigeon', 'wolf', 'cow', 'monkey', 'lion', 'pigeon',
#        'panda', 'elephant', 'monkey', 'cat', 'deer', 'eagle', 'human',
#        'chicken', 'panda', 'deer', 'rabbit', 'sheep', 'chicken', 'human',
#        'cat', 'duck', 'cat', 'lion', 'deer', 'pigeon', 'pigeon', 'bear',
#        'bear', 'lion', 'cow', 'panda', 'dog', 'cat', 'wolf', 'cat',
#        'eagle', 'mouse', 'human', 'panda', 'chicken', 'tiger', 'dog',
#        'chicken', 'monkey', 'wolf', 'bear', 'deer', 'mouse', 'mouse',
#        'cat', 'eagle', 'panda', 'human', 'duck', 'lion', 'dog', 'bear',
#        'deer', 'sheep', 'monkey', 'elephant', 'chicken', 'dog', 'panda',
#        'deer', 'eagle', 'duck', 'bear', 'dog', 'tiger', 'pigeon', 'panda',
#        'chicken', 'eagle', 'duck', 'monkey', 'deer', 'panda', 'eagle',
#        'dog', 'mouse', 'monkey', 'sheep', 'chicken', 'wolf', 'rabbit',
#        'mouse', 'rabbit', 'monkey', 'elephant', 'panda', 'monkey', 'dog',
#        'pigeon', 'rabbit', 'sheep', 'pigeon', 'sheep', 'wolf', 'dog',
#        'wolf', 'lion', 'sheep', 'human', 'monkey', 'eagle', 'deer',
#        'deer', 'wolf', 'chicken', 'duck', 'tiger', 'panda', 'cat',
#        'monkey', 'dog', 'elephant', 'mouse', 'wolf', 'sheep', 'lion',
#        'duck', 'elephant', 'lion', 'deer', 'lion', 'monkey', 'human',
#        'cat', 'rabbit', 'chicken', 'human', 'rabbit', 'bear', 'dog'],
#       dtype='<U8')

# %%
y_test_val = le.transform(y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 y_test_val = le.transform(y_test)
#
# AttributeError: module 'sklearn' has no attribute 'transform'

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred,output_dict=True, zero_division=0)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# bear           0.562500  0.450000  0.500000   20.000000
# cat            0.611111  0.687500  0.647059   32.000000
# chicken        0.666667  0.600000  0.631579   20.000000
# cow            0.857143  0.571429  0.685714   21.000000
# deer           0.857143  0.857143  0.857143   21.000000
# dog            0.545455  0.461538  0.500000   26.000000
# duck           0.850000  0.809524  0.829268   21.000000
# eagle          0.478261  0.550000  0.511628   20.000000
# elephant       0.652174  0.750000  0.697674   20.000000
# human          0.818182  0.900000  0.857143   20.000000
# lion           0.461538  0.600000  0.521739   20.000000
# monkey         0.590909  0.650000  0.619048   20.000000
# mouse          0.352941  0.300000  0.324324   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.695652  0.666667  0.680851   24.000000
# pigeon         0.481481  0.565217  0.520000   23.000000
# rabbit         0.631579  0.600000  0.615385   20.000000
# sheep          0.600000  0.750000  0.666667   20.000000
# tiger          0.882353  0.652174  0.750000   23.000000
# wolf           0.761905  0.800000  0.780488   20.000000
# accuracy       0.640777  0.640777  0.640777    0.640777
# macro avg      0.617850  0.611060  0.609785  412.000000
# weighted avg   0.648506  0.640777  0.639768  412.000000

# %% [markdown]
# ## Grid Search
# - Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = Pipeline([
    ('grayscale',rgb2gray_transform()),
    ('hogtransform',hogtransformer()),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier())
])

# %%
param_grid = [
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['optimal'] 
    },
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['adaptive'],
        'sgd__eta0' : [0.001,0.01],
        
    }
]

# %%
model_grid = GridSearchCV(estimator,
                          param_grid=param_grid,scoring='accuracy',
                          n_jobs=1,cv=3,verbose=2)

# %%
estimator.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'grayscale', 'hogtransform', 'scale', 'sgd', 'hogtransform__cells_per_block', 'hogtransform__orientations', 'hogtransform__pixels_per_cell', 'scale__copy', 'scale__with_mean', 'scale__with_std', 'sgd__alpha', 'sgd__average', 'sgd__class_weight', 'sgd__early_stopping', 'sgd__epsilon', 'sgd__eta0', 'sgd__fit_intercept', 'sgd__l1_ratio', 'sgd__learning_rate', 'sgd__loss', 'sgd__max_iter', 'sgd__n_iter_no_change', 'sgd__n_jobs', 'sgd__penalty', 'sgd__power_t', 'sgd__random_state', 'sgd__shuffle', 'sgd__tol', 'sgd__validation_fraction', 'sgd__verbose', 'sgd__warm_start'])

# %%
model_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   5.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   5.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   5.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   5.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  10.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   5.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   5.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   5.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   4.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   4.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  11.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  11.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  11.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  11.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  11.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  11.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  11.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.2s
# ...
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  17.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  17.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  17.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  19.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  19.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  19.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  19.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  19.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  19.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  19.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  19.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  19.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  15.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  15.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  15.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  15.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  18.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  18.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  22.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  12.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  11.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  10.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  10.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  10.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.8s
# /home/devious/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 162 fits failed out of a total of 486.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 162 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/tmp/ipykernel_29069/3185592662.py", line 20, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "/tmp/ipykernel_29069/3185592662.py", line 20, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "/tmp/ipykernel_29069/3185592662.py", line 14, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/skimage/_shared/utils.py", line 394, in fixed_func
#     return func(*args, **kwargs)
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/skimage/_shared/utils.py", line 348, in fixed_func
#     return func(*args, **kwargs)
#   File "/home/devious/anaconda3/lib/python3.9/site-packages/skimage/feature/_hog.py", line 233, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations),
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/devious/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.72400494 0.71064289 0.72096357
#  0.74043273 0.7416526  0.73435665 0.70455462 0.71792997 0.70516954
#  0.72096801 0.70637833 0.70455684 0.72340996 0.73131529 0.73374284
#  0.71489082 0.71489193 0.71124894        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.71246106 0.70456016 0.70577892 0.7446862  0.72158736 0.72767008
#  0.71915094 0.71854489 0.7112434  0.70274642 0.69119257 0.6905854
#  0.72523699 0.71794105 0.72219452 0.72948604 0.70881253 0.71732391
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.55075696 0.46809616 0.50395654 0.50820337 0.49181214 0.51307177
#  0.58116061 0.47174358 0.52219807 0.53253316 0.52767695 0.52219918
#  0.58359481 0.20729462 0.5003058  0.52765812 0.50457368 0.51063757
#  0.55501044 0.49057455 0.52217813 0.52826196 0.51792797 0.51975722
#  0.56778084 0.47721139 0.52401291 0.53436573 0.5191556  0.53191713
#  0.57872752 0.38784408 0.51732413 0.53069616 0.52157539 0.49848541
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.54468642 0.50881275 0.50942656 0.53069837 0.5343469  0.54832276
#  0.56536547 0.51732856 0.53192378 0.54042187 0.50943321 0.53071278
#  0.57326526 0.48084994 0.51672029 0.54104454 0.51915338 0.53740599
#  0.55136523 0.54101241 0.53982024 0.5525851  0.53616507 0.53678442
#  0.56716813 0.54348096 0.55865786 0.54286271 0.54041965 0.5307028
#  0.5933172  0.50333165 0.52583662 0.54893547 0.53738383 0.52887134]
#   warnings.warn(
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('grayscale', rgb2gray_transform()),
#                                        ('hogtransform', hogtransformer()),
#                                        ('scale', StandardScaler()),
#                                        ('sgd', SGDClassifier())]),
#              n_jobs=1,
#              param_grid=[{'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__learning_rate': ['optimal'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']},
#                          {'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__eta0': [0.001, 0.01],
#                           'sgd__learning_rate': ['adaptive'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']}],
#              scoring='accuracy', verbose=2)

# %%
model_grid.best_params_
# Out:
# {'hogtransform__cells_per_block': (3, 3),
#  'hogtransform__orientations': 9,
#  'hogtransform__pixels_per_cell': (8, 8),
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge'}

# %%
model_grid.best_score_
# Out:
# 0.7446862022965887

# %%
model_best = model_grid.best_estimator_

# %%
y_pred = model_best.predict(x_test)

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred,output_dict=True,zero_division=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# bear           0.625000  0.500000  0.555556   20.000000
# cat            0.848485  0.875000  0.861538   32.000000
# chicken        0.708333  0.850000  0.772727   20.000000
# cow            0.833333  0.714286  0.769231   21.000000
# deer           0.875000  1.000000  0.933333   21.000000
# dog            0.608696  0.538462  0.571429   26.000000
# duck           0.863636  0.904762  0.883721   21.000000
# eagle          0.478261  0.550000  0.511628   20.000000
# elephant       0.736842  0.700000  0.717949   20.000000
# human          0.869565  1.000000  0.930233   20.000000
# lion           0.550000  0.550000  0.550000   20.000000
# monkey         0.714286  0.750000  0.731707   20.000000
# mouse          0.545455  0.600000  0.571429   20.000000
# natural        1.000000  0.000000  0.000000    1.000000
# panda          1.000000  0.875000  0.933333   24.000000
# pigeon         0.761905  0.695652  0.727273   23.000000
# rabbit         0.764706  0.650000  0.702703   20.000000
# sheep          0.727273  0.800000  0.761905   20.000000
# tiger          0.904762  0.826087  0.863636   23.000000
# wolf           0.818182  0.900000  0.857143   20.000000
# accuracy       0.752427  0.752427  0.752427    0.752427
# macro avg      0.761686  0.713962  0.710324  412.000000
# weighted avg   0.755049  0.752427  0.749973  412.000000

# %%
# save the model
pickle.dump(model_best,open('dsa_model_best.pickle','wb'))

# %% [markdown]
# ## Make Pipeline
#
#     {'hogtransform__cells_per_block': (2, 2),
#      'hogtransform__orientations': 10,
#      'hogtransform__pixels_per_cell': (8, 8),
#      'sgd__learning_rate': 'optimal',
#      'sgd__loss': 'hinge'}

# %%
from sklearn.pipeline import make_pipeline

# %%
pipeline1 = make_pipeline(rgb2gray_transform(),
                            hogtransformer(orientations=10,
                                           pixels_per_cell=(8,8),
                                           cells_per_block=(2,2)))

# %%
feature_vector = pipeline1.fit_transform(x_train)

# %%
# standard scaler
scalar = StandardScaler()
transformed_xtrain = scalar.fit_transform(feature_vector)

# %%
model = SGDClassifier(learning_rate='optimal',loss='hinge',alpha=0.01,early_stopping=True)

# %%
model.fit(transformed_xtrain,y_train)
# Out:
# SGDClassifier(alpha=0.01, early_stopping=True)

# %%
# evaluate
feature_vector = pipeline1.fit_transform(x_test)
transformed_x = scalar.transform(feature_vector)
y_pred_test = model.predict(transformed_x)

# %%
cr = pd.DataFrame(metrics.classification_report(y_test,y_pred_test,output_dict=True, zero_division=True)).T
cr
# Out:
#               precision    recall  f1-score     support
# bear           0.722222  0.650000  0.684211   20.000000
# cat            0.818182  0.843750  0.830769   32.000000
# chicken        0.700000  0.700000  0.700000   20.000000
# cow            0.695652  0.761905  0.727273   21.000000
# deer           0.807692  1.000000  0.893617   21.000000
# dog            0.520000  0.500000  0.509804   26.000000
# duck           0.818182  0.857143  0.837209   21.000000
# eagle          0.600000  0.750000  0.666667   20.000000
# elephant       0.684211  0.650000  0.666667   20.000000
# human          1.000000  0.950000  0.974359   20.000000
# lion           0.478261  0.550000  0.511628   20.000000
# monkey         0.625000  0.750000  0.681818   20.000000
# mouse          0.571429  0.600000  0.585366   20.000000
# natural        1.000000  0.000000  0.000000    1.000000
# panda          0.954545  0.875000  0.913043   24.000000
# pigeon         0.833333  0.652174  0.731707   23.000000
# rabbit         0.812500  0.650000  0.722222   20.000000
# sheep          0.937500  0.750000  0.833333   20.000000
# tiger          0.739130  0.739130  0.739130   23.000000
# wolf           0.894737  0.850000  0.871795   20.000000
# accuracy       0.740291  0.740291  0.740291    0.740291
# macro avg      0.760629  0.703955  0.704031  412.000000
# weighted avg   0.750114  0.740291  0.740687  412.000000

# %%
# save models for flask app
pickle.dump(model,open('dsa_image_classification_sgd.pickle','wb'))

# %%
pickle.dump(scalar,open('dsa_scaler.pickle','wb'))

# %% [markdown]
# # Output Analysis

# %%
model_p = pickle.load(open('dsa_model_best.pickle','rb'))

# %%
model_p.get_params()
# Out:
# {'memory': None,
#  'steps': [('grascale', rgb2gray_transform()),
#   ('hogtransform',
#    hogtransformer(cells_per_block=(2, 2), orientations=8, pixels_per_cell=(10, 10))),
#   ('scale', StandardScaler()),
#   ('sgd', SGDClassifier(eta0=0.001))],
#  'verbose': False,
#  'grascale': rgb2gray_transform(),
#  'hogtransform': hogtransformer(cells_per_block=(2, 2), orientations=8, pixels_per_cell=(10, 10)),
#  'scale': StandardScaler(),
#  'sgd': SGDClassifier(eta0=0.001),
#  'hogtransform__cells_per_block': (2, 2),
#  'hogtransform__orientations': 8,
#  'hogtransform__pixels_per_cell': (10, 10),
#  'scale__copy': True,
#  'scale__with_mean': True,
#  'scale__with_std': True,
#  'sgd__alpha': 0.0001,
#  'sgd__average': False,
#  'sgd__class_weight': None,
#  'sgd__early_stopping': False,
#  'sgd__epsilon': 0.1,
#  'sgd__eta0': 0.001,
#  'sgd__fit_intercept': True,
#  'sgd__l1_ratio': 0.15,
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge',
#  'sgd__max_iter': 1000,
#  'sgd__n_iter_no_change': 5,
#  'sgd__n_jobs': None,
#  'sgd__penalty': 'l2',
#  'sgd__power_t': 0.5,
#  'sgd__random_state': None,
#  'sgd__shuffle': True,
#  'sgd__tol': 0.001,
#  'sgd__validation_fraction': 0.1,
#  'sgd__verbose': 0,
#  'sgd__warm_start': False}

# %%
img_test= skimage.io.imread('tiger_test.jpg')
plt.imshow(img_test)

# %%
# image size is 80 x 80
img_resize = skimage.transform.resize(img_test,(80,80))
# rescale into 255
img_rescale = np.array(255*img_resize).astype(np.uint8)
plt.imshow(img_rescale)

# %%
# pass to pipeline model
img_reshape = img_rescale.reshape(-1,80,80,3)
print(img_reshape.shape)
result = model_pipeline.predict(img_reshape)
print(result)
# Out:
# (1, 80, 80, 3)
# [5]

# %%
# Descision Function
distance = model_pipeline.decision_function(img_reshape)[0]
print(distance)
# Out:
# [ 5.75370712 12.24500513  5.76864729 12.20746737  2.7388824  19.30485679
#   7.77682698  3.7492711   8.78288887 10.11721968 16.26141015 13.24395185
#  17.28262812 -0.30971381  1.72096413  0.71980935 18.29393238 15.27077942
#  13.23525647  5.75854397]

# %%
labels = list(data['labels'])
labels.sort()
print(labels)
# Out:
# ['bear', 'cat', 'chicken', 'cow', 'deer', 'dog', 'duck', 'eagle', 'elephant', 'human', 'lion', 'monkey', 'mouse', 'natural', 'panda', 'pigeon', 'rabbit', 'sheep', 'tiger', 'wolf']

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,distance)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# confidence score
mean_distance = distance.mean()
std_distance = distance.std()
z = (distance - mean_distance)/std_distance
z
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])

# %%
mean_distance
# Out:
# 9.496116738372246

# %%
std_distance
# Out:
# 5.976331358171906

# %%
from scipy import stats

# %%
dist = stats.t

# %%
dist.cdf(2.21719813,19)
# Out:
# 0.9804985267531022

# %%
dof = len(z) - 1
pvalues = [dist.cdf(zval,dof) for zval in z]
print(pvalues)
# Out:
# [0.2693157161111511, 0.6746184285442451, 0.2701187789365209, 0.6724013008095282, 0.13613339380733908, 0.94140393774905, 0.38835184849219784, 0.1741646039671521, 0.4531285822198086, 0.5408418151202851, 0.8641432492347143, 0.7309755940591313, 0.8959089406248415, 0.05864698735263532, 0.10440945435151623, 0.07916370072656952, 0.9213186651894776, 0.8269722933653654, 0.7305086321415764, 0.2695755643050099]

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,pvalues)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
import scipy

# %%
aa = scipy.special.softmax(z)

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,aa)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
import scipy

# %%
scipy.stats.zscore(distance)
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])

# %%
z
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])
